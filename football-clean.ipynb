# %%
## Load the dataset and return the first few rows
import glob
import pandas as pd
pd.options.display.max_columns = None
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,8)

# %% [markdown]
# Set up a regex to find the year from the filename

# %%
import re
year_match = re.compile('(\d{4})')

# %% [markdown]
# Couple of functions to transform the scoreline into useful data

# %%
def goals(result: str):
    '''Given a scoreline such as 6-1 returns home and away goals in a dict {home: 6, away: 1}'''
    nums = result.split('-')
    try:
        return {'home': int(nums[0]), 'away': int(nums[1])}
    except Exception:
        return {'home': -1, 'away': -1}

# %%
def outcome(result):
    '''Given a string of the result e.g. 6-1 categorise as either a no-score draw (1), score draw (2), home win (3) or away win (4)'''
    goals_result = goals(result)
    if goals_result['home'] == goals_result['away']:
        if goals_result['home'] == 0:
            return 1
        else:
            return 2
    elif goals_result['home'] > goals_result['away']:
        return 3
    else:
        return 4

# %% [markdown]
# Generate a list of available leagues from the folder names

# %%
league_list = glob.glob('/Users/dev/aicore/Football-predictor/Football-Dataset/*')
league_list = pd.DataFrame(league_list)
league_list.columns = ['folder']
league_list['name'] = league_list['folder'].apply(lambda x: x.split('/')[-1])

# %% [markdown]
# Get all files in a particular folder and list their names

# %%
def get_files(folder):
    league_file_list = glob.glob(folder + '/*')
    league_file_list.sort()
    return league_file_list
league_list['files'] = league_list['folder'].apply(get_files)

# %% [markdown]
# Now run through the list of leagues (folders) and the files in them (in the files column), read in the data, and combine them together into dfs.
#
# Results:
#
# - `overall_team_counts` is a df showing the number of teams involved per league per season (unlikely to be consistent - and indeed not - EPL is a counterexample)
# - `df_full` is the whole data of results across all leagues and seasons

# %%
overall_team_counts = pd.DataFrame()
df_league_lists = []
for index, league in league_list.iterrows():
    league_file_list = league['files']
    team_counts = {}
    df_list = []
    for file in league_file_list:
        df = pd.read_csv(file)
        df.columns = df.columns.str.lower()
        year = year_match.findall(file)[0]
        if len(df.index) == 0:
            # print('No data for {}'.format(year))
            pass
        else:
            df_original = df.copy()
            df_list.append(df)
            team_counts[year] = len(df['home_team'].unique())
            # print('In {} there were {} teams'.format(year, len(df['Home_Team'].unique())))
    overall_team_counts = pd.concat([overall_team_counts, pd.Series(team_counts, name=league['name'])], axis=1)
    df_league_lists.append(pd.concat(df_list, ignore_index=True))
df_full = pd.concat(df_league_lists, ignore_index=True)
overall_team_counts.sort_index()
overall_team_counts = overall_team_counts.fillna(0).astype(int)

# %% [markdown]
# Use the functions defined earlier - `goals` and `outcome` - to transform the scoreline (as a string) into numerical data

# %%
df_full['goals'] = df_full['result'].apply(goals)
# in case we're repeating this operation
try:
    df_full = df_full.drop(['home','away'],axis=1) 
except Exception:
    pass
df_full = pd.concat([df_full, pd.json_normalize(df_full['goals'])], axis=1).drop('goals', axis=1)
# drop errors
df_full = df_full.drop(df_full[df_full.home == -1].index)
df_full['total_goals'] = df_full['home'] + df_full['away']
df_full['outcome'] = df_full['result'].apply(outcome)

# %%
df = df_full.copy()

# %% [markdown]
# ## Additional datasets - join them on
#
# ## first: match info

# %%
match_df = pd.read_csv('additional-data/Match_Info.csv')
match_df.columns = match_df.columns.str.lower()
# match_df.info()
match_df['referee'] = match_df['referee'].str.strip().str.replace('Referee: ','')
match_df['date_dt'] = pd.to_datetime(match_df['date_new'])
match_df['link_parts'] = match_df['link'].str.split('/')
match_df['home_team'] = match_df.apply(lambda row: row['link_parts'][-3], axis=1)
match_df['away_team'] = match_df.apply(lambda row: row['link_parts'][-2], axis=1)
match_df['season'] = match_df.apply(lambda row: row['link_parts'][-1], axis=1)
match_df = match_df.drop(['date_new'], axis=1)

# %%
import difflib
df_teams = df['home_team'].unique()
match_teams = match_df['home_team'].unique()

# %% [markdown]
# Let's use Levenshtein. see https://www.datacamp.com/community/tutorials/fuzzy-string-python

# %%
from fuzzywuzzy import process
# needs a tweak for Manchester to give a helping hand on those two teams
matched_teams = [(d,(process.extractOne(d.replace('Man.','Manchester'), match_teams))[0]) for d in df_teams]

# %%
def team_name_for_link(t):
    matches = [x[1] for x in matched_teams if x[0] == t]
    return (matches if len(matches)>0 else [''])[0]
df['link'] = df.apply(lambda row: '/'.join(['','match',team_name_for_link(row['home_team']),team_name_for_link(row['away_team']),str(row['season'])]).strip().lower().replace(' ','-'), axis=1)

# %%
# duplicates?
print(df['link'].duplicated().value_counts())
print(df[['home_team','away_team','season','league']].duplicated().value_counts())
df.drop_duplicates(subset=['home_team','away_team','season','league'], inplace=True)
# Out:
# False    130890
# True      15602
# Name: link, dtype: int64
# False    132103
# True      14389
# dtype: int64

# %%
df2 = pd.merge(match_df, df, how="inner", on='link')

# %% [markdown]
# ## add team info

# %%
team_df = pd.read_csv('additional-data/Team_Info.csv')
team_df.columns = team_df.columns.str.lower()
team_df['capacity'] = pd.to_numeric(team_df['capacity'].str.replace(',',''))
team_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   team      544 non-null    object
#  1   city      544 non-null    object
#  2   country   544 non-null    object
#  3   stadium   447 non-null    object
#  4   capacity  544 non-null    int64
#  5   pitch     447 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 25.6+ KB

# %%
teams_from_team_data = set(team_df.team)
link_team_data = set(df2.home_team_x)
# originally I had this the other way round, which resulted in multiple matches
matched_teams_team_data = [(d,(process.extractOne(d.replace('Man.','Manchester'), teams_from_team_data))[0]) for d in link_team_data]
matched_teams_team_data
# Out:
# [('msv-duisburg', 'MSV Duisburg'),
#  ('betis', 'Real Betis'),
#  ('pordenone', 'Pordenone'),
#  ('fc-remscheid', 'FC Remscheid'),
#  ('coventry-city', 'Coventry City'),
#  ('real-murcia', 'Real Murcia'),
#  ('fc-martigues', 'FC Martigues'),
#  ('orihuela', 'Orihuela CF'),
#  ('fortuna-dusseldorf', 'Fortuna'),
#  ('hamburger-sv', 'Hamburger SV'),
#  ('arouca', 'Arouca'),
#  ('ciudad-de-murcia', 'Ciudad de Murcia'),
#  ('vfb-oldenburg', 'VfB Oldenburg'),
#  ('leicester-city-fc', 'Leicester'),
#  ('albacete', 'Albacete'),
#  ('treviso', 'Treviso'),
#  ('trapani', 'Trapani'),
#  ('borussia-dortmund', 'B. Dortmund'),
#  ('sporting-braga', 'Sporting Braga'),
#  ('fermana', 'Fermana'),
#  ('bayer-leverkusen', 'B. Leverkusen'),
#  ('sabadell', 'Sabadell'),
#  ('xerez', 'Xerez'),
#  ('cardiff-city-fc', 'Cardiff City'),
#  ('liverpool', 'Liverpool'),
#  ('fc-gueugnon', 'FC Gueugnon'),
#  ('ac-mantova', 'Mantova'),
#  ('stormvogels-telstar', 'SC Telstar'),
#  ('castel-sangro', 'Castel Sangro'),
#  ('reus', 'Reus Deportiu'),
#  ('acireale', 'Acireale'),
#  ('piacenza', 'Piacenza'),
#  ('fortuna-koln', 'Fortuna Köln'),
#  ('luton-town-fc', 'Luton Town'),
#  ('messina', 'Messina'),
#  ('ipswich-town-fc', 'Ipswich Town'),
#  ('ue-lleida', 'Lleida'),
#  ('derby-county-fc', 'Derby County'),
#  ('jong-ajax', 'Jong Ajax'),
#  ('atletico-cp', 'Atlético CP'),
#  ('bolton-wanderers-fc', 'Bolton Wanderers'),
#  ('troyes', 'Troyes'),
#  ('genoa', 'Genoa'),
#  ('wacker-burghausen', 'Wacker Burghausen'),
#  ('nancy', 'Nancy'),
#  ('reutlingen', 'Reutlingen'),
#  ('sc-cambuur-leeuwarden', 'Cambuur'),
#  ('rio-ave', 'Rio Ave'),
#  ('milan', 'Milan'),
#  ('holstein-kiel', 'Holstein Kiel'),
#  ('sunderland-afc', 'Sunderland'),
#  ('rotherham-united', 'Rotherham United'),
#  ('ss-virtus-lanciano-1924', 'Virtus Lanciano'),
#  ('tenerife', 'Tenerife'),
#  ('burnley-fc', 'Burnley'),
#  ('real-madrid', 'Real Madrid'),
#  ('livorno', 'Livorno'),
#  ('almere-city', 'Almere City'),
#  ('belenenses', 'Belenenses'),
#  ('nottingham-forest-fc', 'Nottingham Forest'),
#  ('greuther-furth', 'Greuther Fürth'),
#  ('energie-cottbus', 'Energie Cottbus'),
#  ('amiens-sc', 'Amiens SC'),
#  ('beasancon', 'Ancona'),
#  ('alcoyano', 'Alcoyano'),
#  ('paderborn', 'Paderborn'),
#  ('wattenscheid-09', 'Wattenscheid 09'),
#  ('stuttgarter-kickers', 'Stuttgart'),
#  ('barnsley-fc', 'Barnsley'),
#  ('villarreal', 'Villarreal'),
#  ('norwich-city-fc', 'Norwich City'),
#  ('rimini-calcio', 'Rimini'),
#  ('sheffield-united', 'Sheffield United'),
#  ('wigan-athletic', 'Wigan Athletic'),
#  ('fc-maia', 'FC Maia'),
#  ('academica', 'Académica'),
#  ('beira-mar', 'Beira Mar SC'),
#  ('trofense', 'Trofense'),
#  ('benevento-calcio', 'Calcio'),
#  ('vannes-olympique-club', 'Olympique'),
#  ('aston-villa-fc', 'Aston Villa'),
#  ('rot-weiss-essen', 'Rot-Weiß'),
#  ('plymouth-argyle', 'Plymouth Argyle'),
#  ('vfl-osnabruck', 'VfL Osnabrück'),
#  ('psv', 'PSV'),
#  ('mulhouse', 'FC Mulhouse'),
#  ('real-burgos-cf', 'Real Burgos CF'),
#  ('vicenza-calcio', 'Vicenza '),
#  ('us-boulogne', 'Boulogne'),
#  ('grenoble-foot-38', 'Grenoble'),
#  ('bayern-munchen', 'Bayern München'),
#  ('charlton-athletic-fc', 'Charlton Athletic'),
#  ('crystal-palace-fc', 'Crystal Palace'),
#  ('sportfreunde-s', 'Porto'),
#  ('notts-county', 'Notts County'),
#  ('willem-ii', 'Willem II'),
#  ('athletic-bilbao-b', 'Athletic'),
#  ('sampdoria', 'Sampdoria'),
#  ('clermont-foot', 'Clermont'),
#  ('pacos-ferreira', 'Paços Ferreira'),
#  ('sestao-sport-club', 'Sestao Sport Club'),
#  ('ovarense', 'Ovarense'),
#  ('olympique-marsella', 'Olympique'),
#  ('reggina', 'Reggina'),
#  ('charleville', 'Charleville'),
#  ('portsmouth', 'Portsmouth'),
#  ('preston-north-end', 'Preston North End'),
#  ('hercules', 'Hércules'),
#  ('fsv-frankfurt', 'FSV Frankfurt'),
#  ('sg-dynamo-dresden', 'Dynamo Dresden'),
#  ('heidenheim', 'Heidenheim'),
#  ('rayo-majadahonda', 'Rayo Majadahonda'),
#  ('fc-ingolstadt-04', 'Ingolstadt 04'),
#  ('southend-united', 'Southend United'),
#  ('as-cittadella', 'Cittadella'),
#  ('leeds-united-afc', 'Leeds United'),
#  ('metz', 'Metz'),
#  ('vitesse', 'Vitesse'),
#  ('barcelona-b', 'Barcelona B'),
#  ('as-bari', 'AS Gubbio 1910'),
#  ('guingamp', 'Guingamp'),
#  ('ajax', 'Ajax'),
#  ('ssv-jahn-regensburg', 'Jahn Regensburg'),
#  ('fc-twente-1965', 'Twente 1965'),
#  ('vitoria-guimaraes', 'Vitória'),
#  ('jong-utrecht', 'Jong Utrecht'),
#  ('chemnitzer', 'Chemnitzer'),
#  ('numancia', 'Numancia'),
#  ('graafschap', 'De Graafschap'),
#  ('gutersloh', 'Gutersloh'),
#  ('libourne-saint', 'Libourne Saint Se.'),
#  ('hertha-bsc', 'Hertha BSC'),
#  ('ourense', 'CD Ourense'),
#  ('zwickau', 'Zwickau'),
#  ('queens-park-rangers-fc', 'Queens Park Range.'),
#  ('nice', 'Nice'),
#  ('montpellier-hsc', 'Montpellier'),
#  ('sporting-cp-ii', 'Sporting CP II'),
#  ('magdeburg', 'Magdeburg'),
#  ('cartagena', 'FC Cartagena'),
#  ('hannover-96', 'Hannover 96'),
#  ('udinese', 'Udinese'),
#  ('az', 'AZ Alkmaar'),
#  ('waquehal', 'ES Wasquehal'),
#  ('valence', 'Valence'),
#  ('fc-crotone', 'Crotone'),
#  ('eintracht-trier', 'Eintracht Trier'),
#  ('fc-groningen', 'Groningen'),
#  ('ca-bastia', 'CA Bastia'),
#  ('salamanca', 'UD Salamanca'),
#  ('ad-alcorcon', 'Alcorcón'),
#  ('ucam-murcia-c-f', 'UCAM Murcia'),
#  ('kfc-uerdingen-05', 'KFC Uerdingen 05'),
#  ('calcio-portogruaro-summaga', 'Calcio'),
#  ('wolverhampton', 'Wolves'),
#  ('heracles', 'Heracles'),
#  ('leganes', 'Leganés'),
#  ('toulouse-fc', 'Toulouse'),
#  ('lohuans-cuiseaux', 'Louhans Cuiseaux'),
#  ('huesca', 'Huesca'),
#  ('pescara-calcio', 'Pescara'),
#  ('fc-zwolle', 'Pau FC'),
#  ('us-triestina-calcio', 'Calcio'),
#  ('girona-fc', 'Girona'),
#  ('stuttgart', 'Stuttgart'),
#  ('getafe', 'Getafe'),
#  ('chamois-niortais', 'Niort'),
#  ('maritimo-ii', 'Marítimo II'),
#  ('lens', 'Lens'),
#  ('arsenal', 'Arsenal'),
#  ('nantes', 'Nantes'),
#  ('jong-psv', 'Jong PSV'),
#  ('kickers-offenbach', 'Kickers Offenbach'),
#  ('ecija', 'Écija Balompié'),
#  ('estoril', 'Estoril'),
#  ('rkc-waalwijk', 'RKC Waalwijk'),
#  ('cultural-deportiva-leonesa', 'Lorca Deportiva'),
#  ('real-jaen', 'Real Jaén'),
#  ('fuenlabrada', 'Fuenlabrada'),
#  ('famalicao', 'Famalicão'),
#  ('universidad-lpgc', 'Universidad LPGC'),
#  ('cova-piedade', 'Cova Piedade'),
#  ('dunkerque', 'Dunkerque'),
#  ('vizela', 'Vizela'),
#  ('as-cannes', 'Cannes'),
#  ('alicante', 'Alicante'),
#  ('asd-spezia', 'Spezia'),
#  ('virtus-entella', 'Virtus Entella'),
#  ('lorient', 'Lorient'),
#  ('saarbrucken', 'Saarbrücken'),
#  ('ado-den-haag', 'ADO Den Haag'),
#  ('lubeck', 'VfB Lübeck'),
#  ('catania', 'Catania'),
#  ('rot-weib-oberhausen', 'Rot-Weiß'),
#  ('bristol-rovers', 'Bristol Rovers'),
#  ('walsall', 'Walsall'),
#  ('roda-jc', 'Roda JC'),
#  ('perugia', 'Perugia'),
#  ('grimsby-town', 'Grimsby Town'),
#  ('tranmere-rovers', 'Tranmere Rovers'),
#  ('ac-cesena', 'Cesena'),
#  ('meppen', 'Meppen'),
#  ('jong-twente', 'Jong Twente'),
#  ('rot-weiss-ahlen', 'Rot Weiss Ahlen'),
#  ('blackpool-fc', 'Blackpool'),
#  ('mafra', 'Mafra'),
#  ('sporting-braga-ii', 'Sporting Braga II'),
#  ('sedan', 'Sedan'),
#  ('farense', 'Farense'),
#  ('sd-compostela', 'Compostela'),
#  ('swansea-city-afc', 'Swansea City'),
#  ('ud-palmas', 'UD Oliveirense'),
#  ('west-ham-united', 'West Ham'),
#  ('beziers', 'Béziers'),
#  ('portimonense', 'Portimonense'),
#  ('maritimo', 'Marítimo'),
#  ('babelsberg', 'SV Babelsberg 03'),
#  ('cambridge-united', 'Cambridge United'),
#  ('fc-porto', 'Porto'),
#  ('alverca', 'Alverca'),
#  ('oxford-united', 'Oxford United'),
#  ('agovv-apeldoorn', 'AGOVV Apeldoorn'),
#  ('sochaux', 'Sochaux'),
#  ('pisa-calcio', 'Calcio'),
#  ('fc-erzgebirge-aue', 'Erzgebirge Aue'),
#  ('fc-nurnberg', 'Pau FC'),
#  ('torreense', 'Torreense'),
#  ('granada', 'Granada'),
#  ('real-zaragoza', 'Real Zaragoza'),
#  ('kaiserslautern', 'Kaiserslautern'),
#  ('leixoes', 'Leixões'),
#  ('celta', 'Celta'),
#  ('uc-albinoleffe', 'AlbinoLeffe'),
#  ('bastia', 'Bastia'),
#  ('rayo-vallecano', 'Rayo Vallecano'),
#  ('arminia-bielefeld', 'Arminia Bielefeld'),
#  ('fatima', 'Fatima'),
#  ('napoli', 'Napoli'),
#  ('sparta-rotterdam', 'Sparta Rotterdam'),
#  ('eintracht-frankfurt', 'Eintracht'),
#  ('chelsea-fc', 'Chelsea'),
#  ('palermo', 'Palermo FC'),
#  ('millwall-fc', 'Millwall'),
#  ('vfr-aalen', 'VfR Aalen'),
#  ('vvv', 'VVV Venlo'),
#  ('bologna', 'Bologna'),
#  ('sc-freamunde', 'SC Freamunde'),
#  ('santa-clara', 'CD Santa Clara'),
#  ('deportivo', 'Deportivo'),
#  ('merida-cp', 'Mérida CP'),
#  ('eibar', 'Eibar'),
#  ('internazionale', 'Inter'),
#  ('fc-carl-zeiss-jena', 'Carl Zeiss Jena'),
#  ('academico-viseu', 'Academico Viseu'),
#  ('ejido', 'Poli Ejido'),
#  ('real-aviles-ind', 'Real Jaén'),
#  ('novara-calcio', 'Calcio'),
#  ('granada-74', 'Granada 74'),
#  ('juventus-fc', 'Juventus'),
#  ('rot-weib-erfurt', 'Rot-Weiss Erfurt'),
#  ('fc-augsburg', 'FC Augsburg'),
#  ('stade-lavallois', 'Stade Lavallois'),
#  ('bourg-peronnas', 'Bourg-Péronnas'),
#  ('racing', 'Racing'),
#  ('gillingham', 'Gillingham'),
#  ('nuova-cosenza', 'Nuova Cosenza'),
#  ('savoia-1908', 'FC Savoia 1908'),
#  ('peterborough-u', 'Peterborough'),
#  ('rbc', 'RBC Roosendaal'),
#  ('arles', 'Arles'),
#  ('roma', 'Roma'),
#  ('fc-dordrecht', 'Dordrecht'),
#  ('badajoz', 'CD Badajoz'),
#  ('pistoiese', 'Pistoiese'),
#  ('alzanocene', 'AlzanoCene'),
#  ('schalke-04', 'Schalke 04'),
#  ('as-varese-1910', 'Varese'),
#  ('watford-fc', 'Watford'),
#  ('valencia-cf', 'Valencia'),
#  ('levante', 'Levante'),
#  ('villarreal-b', 'Villarreal B'),
#  ('rm-castilla', 'RM Castilla'),
#  ('mirandes', 'Mirandés'),
#  ('ternana-calcio', 'Ternana Calcio'),
#  ('unterhaching', 'Unterhaching'),
#  ('middlesbrough-fc', 'Middlesbrough'),
#  ('lillestrom', 'Lille'),
#  ('istres', 'Istres'),
#  ('olympique-ales', 'Olympique Alès'),
#  ('bourges', 'Bourges 18'),
#  ('sas-epinal', 'Épinal'),
#  ('preuben-munster', 'Preußen Münster'),
#  ('chambly', 'Chambly'),
#  ('ascoli', 'Ascoli'),
#  ('boavista', 'Boavista'),
#  ('bradford-city', 'Bradford City'),
#  ('sheffield-wednesday-fc', 'Sheffield'),
#  ('lugo', 'Lugo'),
#  ('nacional', 'Nacional'),
#  ('rodez', 'Rodez'),
#  ('fc-eindhoven', 'FC Eindhoven'),
#  ('fidelis-andria', 'Fidelis Andria'),
#  ('gallipoli-calcio', 'Gallipoli '),
#  ('cd-castellon', 'CD Castellón'),
#  ('tottenham-hotspur-fc', 'Tottenham Hotspur'),
#  ('swindon-town', 'Swindon Town'),
#  ('wimbledon-fc', 'Wimbledon FC'),
#  ('creteil-lusitanos', 'Creteil'),
#  ('elche', 'Elche'),
#  ('gondomar', 'Gondomar'),
#  ('porto-ii', 'Porto II'),
#  ('perpignan', 'Perpignan'),
#  ('osasuna', 'Osasuna'),
#  ('chievo', 'Chievo'),
#  ('uniao-madeira', 'União Madeira'),
#  ('spal-1907', 'SPAL'),
#  ('hansa-rostock', 'Hansa Rostock'),
#  ('torino-fc', 'Torino'),
#  ('manchester-united-fc', 'Sète'),
#  ('ud-oliveirense', 'UD Oliveirense'),
#  ('red-star', 'Red Star'),
#  ('real-sociedad', 'Real Jaén'),
#  ('fc-marco', 'FC Marco'),
#  ('everton-fc', 'Everton'),
#  ('sc-olhanense', 'Olhanense'),
#  ('recreativo', 'Recreativo'),
#  ('wehen-wiesbaden', 'Wehen Wiesbaden'),
#  ('svv', 'SVV'),
#  ('auxerre', 'Auxerre'),
#  ('sv-sandhausen', 'Sandhausen'),
#  ('orleans', 'Orléans'),
#  ('ss-juve-stabia', 'Juve Stabia'),
#  ('mallorca-b', 'Mallorca B'),
#  ('ajaccio', 'Ajaccio'),
#  ('almeria', 'Almería'),
#  ('haarlem', 'HFC Haarlem '),
#  ('mallorca', 'Mallorca'),
#  ('homburg', 'FC 08 Homburg'),
#  ('alaves', 'Alavés'),
#  ('ac-arezzo', 'AC Arezzo'),
#  ('fc-den-bosch', 'Den Bosch'),
#  ('wuppertaler-sv', 'Wuppertaler SV'),
#  ('fc-felgueiras', 'FC Felgueiras'),
#  ('as-beauvais', 'Beauvais Oise'),
#  ('desportivo-aves', 'Desportivo Aves'),
#  ('helmond-sport', 'Helmond Sport'),
#  ('bury', 'Bury'),
#  ('gil-vicente', 'Gil Vicente'),
#  ('karlsruher-sc', 'Karlsruher SC'),
#  ('waldhof-mannheim', 'Waldhof Mannheim'),
#  ('oxford-city', 'Oxford City'),
#  ('bordeaux', 'Girondins Bordeaux'),
#  ('havelse', 'Havelse'),
#  ('fc-volendam', 'FC Volendam'),
#  ('berrichonne-chateauroux', 'Chateauroux'),
#  ('angers-sco', 'Angers SCO'),
#  ('tsg-1899-hoffenheim', 'Hoffenheim'),
#  ('benfica', 'Benfica'),
#  ('vitoria-setubal', 'Vitória Setúbal'),
#  ('bristol-city-fc', 'Bristol City'),
#  ('gazelec-ajaccio', 'Gazélec Ajaccio'),
#  ('bayreuth-spvgg', 'Bayreuth SpVgg'),
#  ('as-gubbio-1910', 'AS Gubbio 1910'),
#  ('1860-munchen', '1860 München'),
#  ('brentford', 'Brentford'),
#  ('cd-guadalajara', 'CD Guadalajara'),
#  ('hull-city', 'Hull City'),
#  ('go-ahead-eagles', 'Go Ahead Eagles'),
#  ('ud-vecindario', 'Vecindario'),
#  ('reading-fc', 'Reading'),
#  ('latina', 'Latina'),
#  ('us-sassuolo-calcio', 'Calcio'),
#  ('monaco', 'Monaco'),
#  ('espinho', 'Espinho'),
#  ('venezia', 'Venezia'),
#  ('stade-briochin', 'Stade Briochin'),
#  ('tondela', 'Tondela'),
#  ('saint-etienne', 'Saint-Étienne'),
#  ('stade-rennes', 'Stade Rennais'),
#  ('stade-reims', 'Stade de Reims'),
#  ('strasbourg', 'Strasbourg'),
#  ('excelsior', 'Excelsior'),
#  ('nec', 'NEC Nijmegen'),
#  ('logrones-cd', 'CD Logroñés'),
#  ('cf-extremadura', 'CF Extremadura'),
#  ('fc-oss', 'FC Omniworld'),
#  ('pontevedra-cf', 'Pontevedra'),
#  ('blau-weiss-1890-berlin', 'Union Berlin'),
#  ('heerenveen', 'Heerenveen'),
#  ('evian-thonon-gaillard', 'Evian Thonon Gail.'),
#  ('ponferradina-sd', 'Ponferradina'),
#  ('werder-bremen', 'Werder Bremen'),
#  ('penafiel', 'Penafiel'),
#  ('brescia', 'Brescia'),
#  ('naval', 'Naval'),
#  ('espanyol', 'Espanyol'),
#  ('rouen-1899', 'FC Rouen 1899'),
#  ('tennis-borussia', 'Tennis Borussia'),
#  ('benfica-ii', 'Benfica II'),
#  ('lecce', 'Lecce'),
#  ('tours-fc', 'Tours'),
#  ('parma-fc', 'Parma'),
#  ('atalanta', 'Atalanta'),
#  ('ulm', 'Ulm'),
#  ('sporting-toulon', 'Sporting Toulon'),
#  ('omniworld', 'FC Omniworld'),
#  ('blackburn-rovers-fc', 'Blackburn Rovers'),
#  ('ac-monza-brianza-1912', 'AC Monza'),
#  ('tus-koblenz', 'TuS Koblenz'),
#  ('quevilly', 'Quevilly'),
#  ('algeciras-cf', 'Algeciras'),
#  ('mvv', 'MVV Maastricht'),
#  ('oldham-athletic-afc', 'Oldham Athletic'),
#  ('cadiz', 'Cádiz'),
#  ('varzim', 'Varzim'),
#  ('siena', 'Siena'),
#  ('alemannia-aachen', 'Alemannia Aachen'),
#  ('estrela-amadora', 'Estrela Amadora'),
#  ('manchester-city-fc', 'Sète'),
#  ('ancona', 'Ancona'),
#  ('gimnastic-tarragona', 'Gimnàstic'),
#  ('cagliari', 'Cagliari'),
#  ('valladolid', 'Real Valladolid'),
#  ('moreirense-fc', 'Moreirense'),
#  ('darmstadt-98', 'Darmstadt 98'),
#  ('como', 'Como'),
#  ('us-cremonese', 'Cremonese'),
#  ('1-fc-union-berlin', 'Union Berlin'),
#  ('fortuna-sittard', 'Fortuna Sittard'),
#  ('us-avellino', 'Avellino'),
#  ('sc-freiburg', 'SC Freiburg'),
#  ('hellas-verona-fc', 'Hellas Verona'),
#  ('malaga', 'Málaga'),
#  ('racing-club-ferrol', 'Racing Ferrol'),
#  ('calcio-padova', 'Calcio'),
#  ('huddersfield-town-fc', 'Huddersfield Town'),
#  ('salernitana-calcio-1919', 'Salernitana'),
#  ('cd-toledo', 'CD Toledo'),
#  ('sporting-covilha', 'Sporting CP'),
#  ('modena-fc', 'Modena'),
#  ('us-grosseto', 'Grosseto'),
#  ('chaves', 'Chaves'),
#  ('newcastle-united-fc', 'Newcastle'),
#  ('nac-breda', 'NAC Breda'),
#  ('feyenoord', 'Feyenoord'),
#  ('schweinfurt', 'Schweinfurt'),
#  ('real-oviedo', 'Real Oviedo'),
#  ('tirsense', 'Tirsense'),
#  ('caen', 'Caen'),
#  ('stoke-city', 'Stoke City'),
#  ('fiorentina', 'Fiorentina'),
#  ('lorca-deportiva-cf-sad', 'Lorca Deportiva'),
#  ('fulham', 'Fulham'),
#  ('sevilla', 'Sevilla'),
#  ('uniao-leiria', 'União de Leiria'),
#  ('veendam', 'BV Veendam '),
#  ('atletico-marbella', 'Atlético Marbella'),
#  ('rb-leipzig', 'RB Leipzig'),
#  ('stade-brestois-29', 'Stade Brestois'),
#  ('dijon-fco', 'Dijon FCO'),
#  ('crewe-alexandra', 'Crewe Alexandra'),
#  ('lazio', 'Lazio'),
#  ('feirense', 'Feirense'),
#  ('fc-catanzaro', 'Catanzaro'),
#  ('afc-bournemouth', 'AFC Bournemouth'),
#  ('port-vale', 'Port Vale'),
#  ('pau', 'Pau FC'),
#  ('west-bromwich', 'West Bromwich Alb.'),
#  ('fc-utrecht', 'Utrecht'),
#  ('valenciennes-afc', 'Valenciennes'),
#  ('salgueiros', 'SC Salgueiros'),
#  ('barcelona', 'Barcelona'),
#  ('emmen', 'Emmen'),
#  ('olympique-lyonnais', 'Olympique Lyonnais'),
#  ('hessen-kassel', 'Hessen Kassel'),
#  ('wolfsburg', 'Wolfsburg'),
#  ('uniao-lamas', 'Uniao Lamas'),
#  ('southampton-fc', 'Southampton'),
#  ('racing-paris', 'Racing Paris'),
#  ('lokomotive-leipzig', 'Lokomotive Leipzig'),
#  ('wycombe-wanderers', 'Wycombe Wanderers'),
#  ('wurzburger-kickers', 'Würzburger'),
#  ('campomaiorense', 'Campomaiorense'),
#  ('frosinone-calcio', 'Calcio'),
#  ('ud-logrones', 'UD Logroñés'),
#  ('empoli-fc', 'Empoli'),
#  ('hallescher-fc', 'Hallescher FC'),
#  ('nocerina', 'Nocerina'),
#  ('us-pro-vercelli-calcio', 'Pro Vercelli'),
#  ('birmingham-city-fc', 'Birmingham City'),
#  ('bochum', 'VfL Bochum'),
#  ('brighton-amp-hov', 'Brighton Hove Alb.'),
#  ('stockport-county', 'Stockport County'),
#  ('cd-malaga', 'CD Málaga'),
#  ('cordoba', 'Córdoba'),
#  ('carpi', 'Carpi'),
#  ('llagostera', 'Llagostera'),
#  ('figueres', 'UE Figueres')]

# %%
def team_name_for_link_team_data(t):
    matches = [x[0] for x in matched_teams_team_data if x[1] == t]
    return (matches if len(matches)>0 else [''])[0]
team_df['matched_team'] = team_df.apply(lambda row: team_name_for_link_team_data(row['team']), axis=1)

# %%
# Brighton is particularly problematic! Let's see if it gets picked up
team_df[team_df.city=='Brighton']
# Out:
#                   team      city  country  \
# 99  Brighton Hove Alb.  Brighton  England
#
#                                    stadium  capacity    pitch  \
# 99  The American Express Community Stadium     30750  Natural
#
#         matched_team
# 99  brighton-amp-hov

# %%
team_df[team_df['matched_team']=='crystal-palace-fc']
# Out:
#                team     city  country        stadium  capacity    pitch  \
# 126  Crystal Palace  Londres  England  Selhurst Park     26309  Natural
#
#           matched_team
# 126  crystal-palace-fc

# %%
df3 = pd.merge(df2, team_df, how="inner", left_on="home_team_x", right_on="matched_team")
df3
# Out:
#                                                   link            referee  \
# 0          /match/saarbrucken/stuttgarter-kickers/1990  Hans-Jürgen Weber
# 1                  /match/saarbrucken/hannover-96/1990      Eugen Strigel
# 2                       /match/saarbrucken/meppen/1990     Siegbert Rubel
# 3       /match/saarbrucken/blau-weiss-1890-berlin/1990  Wilfried Heitmann
# 4                /match/saarbrucken/vfl-osnabruck/1990     Karl Gangkofer
# ...                                                ...                ...
# 109238                       /match/bourges/nancy/1994         Marc Flosi
# 109239                    /match/bourges/red-star/1994
# 109240                       /match/bourges/sedan/1994    Stéphane Moulin
# 109241            /match/bourges/chamois-niortais/1994        Hervé Bayet
# 109242                   /match/bourges/dunkerque/1994       Stéphane Bré
#
#         home_yellow  home_red  away_yellow  away_red             date_dt  \
# 0               0.0       0.0          3.0       0.0 1989-07-29 15:00:00
# 1               0.0       0.0          3.0       0.0 1989-08-12 15:00:00
# 2               0.0       0.0          3.0       0.0 1989-08-23 19:30:00
# 3               0.0       0.0          0.0       0.0 1989-09-02 15:00:00
# 4               1.0       0.0          2.0       0.0 1989-09-17 15:00:00
# ...             ...       ...          ...       ...                 ...
# 109238          0.0       0.0          0.0       1.0 1993-09-01 00:00:00
# 109239          0.0       0.0          0.0       1.0 1994-03-05 00:00:00
# 109240          0.0       0.0          0.0       1.0 1993-09-11 00:00:00
# 109241          0.0       0.0          0.0       0.0 1993-10-27 00:00:00
# 109242          0.0       0.0          0.0       1.0 1993-08-04 00:00:00
#
#                                                link_parts  home_team_x  \
# 0       [, match, saarbrucken, stuttgarter-kickers, 1990]  saarbrucken
# 1               [, match, saarbrucken, hannover-96, 1990]  saarbrucken
# 2                    [, match, saarbrucken, meppen, 1990]  saarbrucken
# 3       [, match, saarbrucken, blau-weiss-1890-berlin,...  saarbrucken
# 4             [, match, saarbrucken, vfl-osnabruck, 1990]  saarbrucken
# ...                                                   ...          ...
# 109238                    [, match, bourges, nancy, 1994]      bourges
# 109239                 [, match, bourges, red-star, 1994]      bourges
# 109240                    [, match, bourges, sedan, 1994]      bourges
# 109241         [, match, bourges, chamois-niortais, 1994]      bourges
# 109242                [, match, bourges, dunkerque, 1994]      bourges
#
#                    away_team_x season_x  home_team_y            away_team_y  \
# 0          stuttgarter-kickers     1990  Saarbrücken    Stuttgarter Kickers
# 1                  hannover-96     1990  Saarbrücken            Hannover 96
# 2                       meppen     1990  Saarbrücken                 Meppen
# 3       blau-weiss-1890-berlin     1990  Saarbrücken  Blau-Weiß 1890 Berlin
# 4                vfl-osnabruck     1990  Saarbrücken          VfL Osnabrück
# ...                        ...      ...          ...                    ...
# 109238                   nancy     1994   Bourges 18                  Nancy
# 109239                red-star     1994   Bourges 18               Red Star
# 109240                   sedan     1994   Bourges 18                  Sedan
# 109241        chamois-niortais     1994   Bourges 18                  Niort
# 109242               dunkerque     1994   Bourges 18              Dunkerque
#
#        result  season_y  round   league  home  away  total_goals  outcome  \
# 0         1-0      1990      1   2_liga     1     0            1        3
# 1         2-0      1990      3   2_liga     2     0            2        3
# 2         4-0      1990      5   2_liga     4     0            4        3
# 3         1-1      1990      7   2_liga     1     1            2        2
# 4         7-1      1990      9   2_liga     7     1            8        3
# ...       ...       ...    ...      ...   ...   ...          ...      ...
# 109238    2-0      1994      9  ligue_2     2     0            2        3
# 109239    0-1      1994     31  ligue_2     0     1            1        4
# 109240    1-2      1994     10  ligue_2     1     2            3        4
# 109241    1-1      1994     18  ligue_2     1     1            2        2
# 109242    1-1      1994      3  ligue_2     1     1            2        2
#
#                team         city  country              stadium  capacity  \
# 0       Saarbrücken  Saarbrücken  Germany  Stadion Ludwigspark     35286
# 1       Saarbrücken  Saarbrücken  Germany  Stadion Ludwigspark     35286
# 2       Saarbrücken  Saarbrücken  Germany  Stadion Ludwigspark     35286
# 3       Saarbrücken  Saarbrücken  Germany  Stadion Ludwigspark     35286
# 4       Saarbrücken  Saarbrücken  Germany  Stadion Ludwigspark     35286
# ...             ...          ...      ...                  ...       ...
# 109238   Bourges 18      Bourges   France                  NaN     13000
# 109239   Bourges 18      Bourges   France                  NaN     13000
# 109240   Bourges 18      Bourges   France                  NaN     13000
# 109241   Bourges 18      Bourges   France                  NaN     13000
# 109242   Bourges 18      Bourges   France                  NaN     13000
#
#           pitch matched_team
# 0       Natural  saarbrucken
# 1       Natural  saarbrucken
# 2       Natural  saarbrucken
# 3       Natural  saarbrucken
# 4       Natural  saarbrucken
# ...         ...          ...
# 109238      NaN      bourges
# 109239      NaN      bourges
# 109240      NaN      bourges
# 109241      NaN      bourges
# 109242      NaN      bourges
#
# [109243 rows x 28 columns]

# %% [markdown]
# # ELO

# %%
import pickle
elo_dict = pickle.load(open('additional-data/elo_dict.pkl', 'rb'))
elo = pd.DataFrame.from_dict(elo_dict).transpose()
elo.columns = elo.columns.str.lower()

# %%
elo['link_parts'] = elo.index.str.split('/')
elo['home_team'] = elo.apply(lambda row: row['link_parts'][-3], axis=1)
elo['away_team'] = elo.apply(lambda row: row['link_parts'][-2], axis=1)
elo['season'] = elo.apply(lambda row: int(str(row['link_parts'][-1])[:4]), axis=1)
elo['link_index'] = elo.apply(lambda row: str(row['link_parts'][-1])[4:], axis=1)
elo['link'] = elo.apply(lambda row: '/'.join(['','match',row['home_team'],row['away_team'],str(row['season'])]), axis=1)
elo = elo.drop(['link_parts'], axis=1)

# %%
elo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 132111 entries, https://www.besoccer.com/match/saarbrucken/stuttgarter-kickers/19903487 to https://www.besoccer.com/match/chievo/pisa-calcio/2021103065
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   elo_home    122314 non-null  float64
#  1   elo_away    122314 non-null  float64
#  2   home_team   132111 non-null  object
#  3   away_team   132111 non-null  object
#  4   season      132111 non-null  int64
#  5   link_index  132111 non-null  object
#  6   link        132111 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 8.1+ MB

# %%
df3_teams = set(df3.home_team_x)
# lower case fixes sd-Compostela which was the only non-match
elo_teams = set(elo.home_team.str.lower())
# empty set difference shows that all teams in our data so far (df3) are included in elo
df3_teams.difference(elo_teams)
# Out:
# set()

# %%
elo.home_team = elo.home_team.str.lower()

# %%
df4 = pd.merge(df3, elo, how="left", on="link")
# clean up - drop some of the columns created by the joins
df4.drop(['link_parts','home_team_y','away_team_y','season_y','team','matched_team','home_team','away_team','season'], axis=1, inplace=True)
df4.rename(columns={'home_team_x':'home_team','away_team_x':'away_team','season_x':'season','home':'home_goals','away':'away_goals'}, inplace=True)
df4
# Out:
#                                                   link            referee  \
# 0          /match/saarbrucken/stuttgarter-kickers/1990  Hans-Jürgen Weber
# 1                  /match/saarbrucken/hannover-96/1990      Eugen Strigel
# 2                       /match/saarbrucken/meppen/1990     Siegbert Rubel
# 3       /match/saarbrucken/blau-weiss-1890-berlin/1990  Wilfried Heitmann
# 4                /match/saarbrucken/vfl-osnabruck/1990     Karl Gangkofer
# ...                                                ...                ...
# 109242                       /match/bourges/nancy/1994         Marc Flosi
# 109243                    /match/bourges/red-star/1994
# 109244                       /match/bourges/sedan/1994    Stéphane Moulin
# 109245            /match/bourges/chamois-niortais/1994        Hervé Bayet
# 109246                   /match/bourges/dunkerque/1994       Stéphane Bré
#
#         home_yellow  home_red  away_yellow  away_red             date_dt  \
# 0               0.0       0.0          3.0       0.0 1989-07-29 15:00:00
# 1               0.0       0.0          3.0       0.0 1989-08-12 15:00:00
# 2               0.0       0.0          3.0       0.0 1989-08-23 19:30:00
# 3               0.0       0.0          0.0       0.0 1989-09-02 15:00:00
# 4               1.0       0.0          2.0       0.0 1989-09-17 15:00:00
# ...             ...       ...          ...       ...                 ...
# 109242          0.0       0.0          0.0       1.0 1993-09-01 00:00:00
# 109243          0.0       0.0          0.0       1.0 1994-03-05 00:00:00
# 109244          0.0       0.0          0.0       1.0 1993-09-11 00:00:00
# 109245          0.0       0.0          0.0       0.0 1993-10-27 00:00:00
# 109246          0.0       0.0          0.0       1.0 1993-08-04 00:00:00
#
#           home_team               away_team season result  round   league  \
# 0       saarbrucken     stuttgarter-kickers   1990    1-0      1   2_liga
# 1       saarbrucken             hannover-96   1990    2-0      3   2_liga
# 2       saarbrucken                  meppen   1990    4-0      5   2_liga
# 3       saarbrucken  blau-weiss-1890-berlin   1990    1-1      7   2_liga
# 4       saarbrucken           vfl-osnabruck   1990    7-1      9   2_liga
# ...             ...                     ...    ...    ...    ...      ...
# 109242      bourges                   nancy   1994    2-0      9  ligue_2
# 109243      bourges                red-star   1994    0-1     31  ligue_2
# 109244      bourges                   sedan   1994    1-2     10  ligue_2
# 109245      bourges        chamois-niortais   1994    1-1     18  ligue_2
# 109246      bourges               dunkerque   1994    1-1      3  ligue_2
#
#         home_goals  away_goals  total_goals  outcome         city  country  \
# 0                1           0            1        3  Saarbrücken  Germany
# 1                2           0            2        3  Saarbrücken  Germany
# 2                4           0            4        3  Saarbrücken  Germany
# 3                1           1            2        2  Saarbrücken  Germany
# 4                7           1            8        3  Saarbrücken  Germany
# ...            ...         ...          ...      ...          ...      ...
# 109242           2           0            2        3      Bourges   France
# 109243           0           1            1        4      Bourges   France
# 109244           1           2            3        4      Bourges   France
# 109245           1           1            2        2      Bourges   France
# 109246           1           1            2        2      Bourges   France
#
#                     stadium  capacity    pitch  elo_home  elo_away link_index
# 0       Stadion Ludwigspark     35286  Natural      56.0      59.0       3487
# 1       Stadion Ludwigspark     35286  Natural      56.0      60.0       3507
# 2       Stadion Ludwigspark     35286  Natural      57.0      53.0       3533
# 3       Stadion Ludwigspark     35286  Natural      57.0      56.0       3553
# 4       Stadion Ludwigspark     35286  Natural      57.0      52.0       3575
# ...                     ...       ...      ...       ...       ...        ...
# 109242                  NaN     13000      NaN       NaN       NaN      35314
# 109243                  NaN     13000      NaN       NaN       NaN      35553
# 109244                  NaN     13000      NaN       NaN       NaN      35322
# 109245                  NaN     13000      NaN       NaN       NaN      35411
# 109246                  NaN     13000      NaN       NaN       NaN      35251
#
# [109247 rows x 25 columns]

# %%
fulldf = df4.copy()

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Newly-promoted teams (and newly-relegated)
#
# Highlight which teams are new in the league this season

# %%
# try this for premier_league 2018 as an example
def teams(league,season):
    return set(fulldf[(fulldf['league']==league) & (fulldf['season']==season)].home_team)
pl18_teams = teams('premier_league','2018')
pl17_teams = teams('premier_league','2017')
pl18_teams.difference(pl17_teams)
# Out:
# {'brighton-amp-hov', 'huddersfield-town-fc', 'newcastle-united-fc'}

# %%
# we have to connect pairs of leagues so we can look at relegation and promotion between them

league_pairings = [
    ('ligue_1','ligue_2'),
    ('eredivisie','eerste_divisie'),
    ('premier_league','championship'),
    ('primera_division','segunda_division'),
    ('primeira_liga','segunda_liga'),
    ('serie_a','serie_b'),
    ('bundesliga','2_liga')
]

# returns the league that's connected (same country) to the one supplied, and t/f as to whether the league supplied as l is the top league
def pairing(l):
    pair = [p for p in league_pairings if l in p][0]
    return ([t for t in pair if t != l][0], l == pair[0]) 

# eg

# %%
def teams_new_this_season(league, season):
    previous_season = teams(league,str(int(season)-1))
    this_season = teams(league, season)
    return list(this_season.difference(previous_season))

def teams_gone_from_last_season(league, season):
    previous_season = teams(league,str(int(season)-1))
    this_season = teams(league, season)
    return list(previous_season.difference(this_season))

# %%
# returns a 2-tuple of (promoted teams, relegated teams) - i.e. lists of teams in this league this season who arrived by either promotion or relegation
def promoted_teams(league, season):
    previous_season = teams(league,str(int(season)-1))
    this_season = teams(league, season)
    if len(previous_season) == 0:
        return ([],[])
    new_this_season = teams_new_this_season(league, season)
    connected = pairing(league)
    if not connected[1]: # league is NOT the top league so we need to look at relegated teams too
        relegated_teams = teams_gone_from_last_season(connected[0], season)
        promoted_teams = list(set(new_this_season).difference(set(relegated_teams)))
        return (promoted_teams, relegated_teams)
    else:
        return (new_this_season, [])

# %%
promoted_teams('championship','2000')
# Out:
# (['fulham', 'walsall'],
#  ['nottingham-forest-fc', 'blackburn-rovers-fc', 'charlton-athletic-fc'])

# %%
leagues = list(set(fulldf.league))
seasons = list(set(fulldf.season))
df_moved_teams = pd.DataFrame(columns=leagues)
df_moved_teams['season'] = seasons
df_moved_teams.set_index('season', inplace=True)
for league in leagues:
    for season in seasons:
        df_moved_teams.at[season,league] = promoted_teams(league, season)
df_moved_teams
# Out:
#                                            eerste_divisie  \
# season
# 1991                                             ([], [])
# 1996                                             ([], [])
# 1990                                             ([], [])
# 2005    ([heracles, fc-oss, go-ahead-eagles, excelsior...
# 2006    ([sc-cambuur-leeuwarden, vvv, mvv, fc-zwolle],...
# 2021    ([sc-cambuur-leeuwarden, stormvogels-telstar, ...
# 1994                                             ([], [])
# 2007    ([graafschap, fc-den-bosch, agovv-apeldoorn, v...
# 2018                                             ([], [])
# 2008    ([sc-cambuur-leeuwarden, fc-volendam, go-ahead...
# 2010    ([sc-cambuur-leeuwarden, go-ahead-eagles, fc-e...
# 1993                                             ([], [])
# 2000    ([go-ahead-eagles, ado-den-haag, rbc, fc-eindh...
# 1995                                             ([], [])
# 1992                                             ([], [])
# 2004    ([vvv, haarlem, agovv-apeldoorn, sparta-rotter...
# 1999    ([vvv, fc-den-bosch, haarlem, fc-oss], [fc-vol...
# 2014    ([jong-ajax, sparta-rotterdam, jong-twente, ex...
# 2012    ([fc-oss, sparta-rotterdam, veendam], [willem-...
# 2002    ([sc-cambuur-leeuwarden, fc-dordrecht, go-ahea...
# 2015                   ([], [roda-jc, nec, rkc-waalwijk])
# 2011    ([stormvogels-telstar, fc-den-bosch, almere-ci...
# 2001    ([heracles, stormvogels-telstar], [sc-cambuur-...
# 2017                                             ([], [])
# 2009    ([fc-den-bosch, veendam, helmond-sport, fc-dor...
# 2019                                             ([], [])
# 1998    ([stormvogels-telstar, ado-den-haag, fc-zwolle...
# 2003    ([emmen, fc-oss, ado-den-haag, helmond-sport],...
# 2013    ([fc-volendam, stormvogels-telstar, almere-cit...
# 2016                                             ([], [])
# 2020                                             ([], [])
# 1997                                             ([], [])
#
#                                                   ligue_1  \
# season
# 1991    ([stade-rennes, monaco, bordeaux, as-cannes, a...
# 1996                        ([guingamp, fc-gueugnon], [])
# 1990                                             ([], [])
# 2005                  ([caen, saint-etienne, istres], [])
# 2006                                ([troyes, nancy], [])
# 2021                                ([lens, lorient], [])
# 1994          ([as-cannes, angers-sco, fc-martigues], [])
# 2007             ([lorient, sedan, valenciennes-afc], [])
# 2018                ([troyes, strasbourg, amiens-sc], [])
# 2008                       ([caen, metz, strasbourg], [])
# 2010           ([montpellier-hsc, us-boulogne, lens], [])
# 1993       ([strasbourg, bordeaux, valenciennes-afc], [])
# 2000                 ([troyes, saint-etienne, sedan], [])
# 1995                   ([stade-rennes, nice, bastia], [])
# 1992                                         ([lens], [])
# 2004                            ([metz, toulouse-fc], [])
# 1999                      ([nancy, sochaux, lorient], [])
# 2014                     ([guingamp, monaco, nantes], [])
# 2012    ([evian-thonon-gaillard, ajaccio, dijon-fco], [])
# 2002            ([montpellier-hsc, sochaux, lorient], [])
# 2015                             ([caen, lens, metz], [])
# 2011               ([arles, caen, stade-brestois-29], [])
# 2001            ([guingamp, toulouse-fc, lillestrom], [])
# 2017                       ([dijon-fco, metz, nancy], [])
# 2009                     ([nantes, grenoble-foot-38], [])
# 2019                                  ([stade-reims], [])
# 1998         ([berrichonne-chateauroux, toulouse-fc], [])
# 2003                    ([ajaccio, nice, strasbourg], [])
# 2013                  ([troyes, bastia, stade-reims], [])
# 2016          ([troyes, angers-sco, gazelec-ajaccio], [])
# 2020                      ([metz, stade-brestois-29], [])
# 1997                                  ([caen, nancy], [])
#
#                                          segunda_division  \
# season
# 1991    ([ue-lleida, albacete, orihuela], [celta, cd-m...
# 1996    ([sestao-sport-club, ecija, almeria, alaves], ...
# 1990                                             ([], [])
# 2005    ([pontevedra-cf, ue-lleida, gimnastic-tarragon...
# 2006    ([cd-castellon, rm-castilla, hercules], [numan...
# 2021    ([sabadell, cartagena, cd-castellon, ud-logron...
# 1994    ([real-murcia, leganes, cd-toledo, hercules], ...
# 2007    ([ud-palmas, salamanca, ud-vecindario, ponferr...
# 2018    ([cultural-deportiva-leonesa, barcelona-b, alb...
# 2008    ([granada-74, cordoba, racing-club-ferrol, eib...
# 2010    ([villarreal-b, cartagena, cadiz], [betis, rec...
# 1993    ([lugo, badajoz, villarreal, atletico-marbella...
# 2000    ([cordoba, elche, getafe, levante], [tenerife,...
# 1995    ([ourense, salamanca, cf-extremadura, getafe],...
# 1992    ([barcelona-b, racing, sd-compostela, rm-casti...
# 2004    ([cadiz, algeciras-cf, ciudad-de-murcia], [rec...
# 1999    ([mallorca-b, malaga, barcelona-b, recreativo]...
# 2014    ([tenerife, real-jaen, alaves, eibar], [real-z...
# 2012    ([sabadell, real-murcia, cd-guadalajara, alcoy...
# 2002    ([gimnastic-tarragona, xerez, ejido], [numanci...
# 2015    ([leganes, racing, albacete, llagostera], [bet...
# 2011    ([granada, barcelona-b, ponferradina-sd, ad-al...
# 2001    ([universidad-lpgc, real-murcia, real-jaen, ra...
# 2017    ([reus, cadiz, ucam-murcia-c-f], [getafe, rayo...
# 2009    ([alicante, girona-fc, huesca, rayo-vallecano]...
# 2019    ([mallorca, rayo-majadahonda, elche], [ud-palm...
# 1998    ([numancia, xerez, real-jaen, elche], [logrone...
# 2003    ([almeria, sd-compostela, getafe], [real-zarag...
# 2013    ([lugo, rm-castilla, mirandes, ponferradina-sd...
# 2016    ([gimnastic-tarragona, real-oviedo, huesca], [...
# 2020    ([fuenlabrada, racing, mirandes, ponferradina-...
# 1997    ([ourense, ud-palmas, levante], [salamanca, al...
#
#                                            premier_league  \
# season
# 1991    ([leeds-united-afc, sheffield-united, sunderla...
# 1996        ([middlesbrough-fc, bolton-wanderers-fc], [])
# 1990                                             ([], [])
# 2005    ([crystal-palace-fc, west-bromwich, norwich-ci...
# 2006    ([wigan-athletic, sunderland-afc, west-ham-uni...
# 2021      ([leeds-united-afc, fulham, west-bromwich], [])
# 1994    ([swindon-town, newcastle-united-fc, west-ham-...
# 2007     ([watford-fc, sheffield-united, reading-fc], [])
# 2018    ([brighton-amp-hov, huddersfield-town-fc, newc...
# 2008    ([derby-county-fc, sunderland-afc, birmingham-...
# 2010    ([wolverhampton, burnley-fc, birmingham-city-f...
# 1993    ([blackburn-rovers-fc, ipswich-town-fc, middle...
# 2000    ([watford-fc, bradford-city, sunderland-afc], [])
# 1995    ([nottingham-forest-fc, crystal-palace-fc, lei...
# 1992    ([sheffield-wednesday-fc, oldham-athletic-afc,...
# 2004    ([wolverhampton, portsmouth, leicester-city-fc...
# 1999    ([nottingham-forest-fc, middlesbrough-fc, char...
# 2014    ([crystal-palace-fc, cardiff-city-fc, hull-cit...
# 2012    ([swansea-city-afc, queens-park-rangers-fc, no...
# 2002    ([blackburn-rovers-fc, fulham, bolton-wanderer...
# 2015    ([leicester-city-fc, burnley-fc, queens-park-r...
# 2011    ([blackpool-fc, west-bromwich, newcastle-unite...
# 2001        ([charlton-athletic-fc, ipswich-town-fc], [])
# 2017      ([middlesbrough-fc, burnley-fc, hull-city], [])
# 2009         ([stoke-city, west-bromwich, hull-city], [])
# 2019       ([fulham, wolverhampton, cardiff-city-fc], [])
# 1998    ([crystal-palace-fc, barnsley-fc, bolton-wande...
# 2003            ([west-bromwich, birmingham-city-fc], [])
# 2013    ([southampton-fc, reading-fc, west-ham-united]...
# 2016    ([watford-fc, afc-bournemouth, norwich-city-fc...
# 2020    ([sheffield-united, aston-villa-fc, norwich-ci...
# 1997    ([leicester-city-fc, derby-county-fc, sunderla...
#
#                                                   serie_a  \
# season
# 1991                ([parma-fc, torino-fc, cagliari], [])
# 1996    ([piacenza, atalanta, vicenza-calcio, udinese]...
# 1990                                             ([], [])
# 2005                                             ([], [])
# 2006                                             ([], [])
# 2021     ([fc-crotone, benevento-calcio, asd-spezia], [])
# 1994                ([us-cremonese, piacenza, lecce], [])
# 2007                 ([catania, torino-fc, atalanta], [])
# 2018    ([spal-1907, benevento-calcio, hellas-verona-f...
# 2008                   ([juventus-fc, genoa, napoli], [])
# 2010                   ([livorno, parma-fc, as-bari], [])
# 1993             ([pescara-calcio, brescia, udinese], [])
# 2000                                             ([], [])
# 1995                 ([brescia, fiorentina, as-bari], [])
# 1992       ([us-cremonese, ascoli, hellas-verona-fc], [])
# 2004                                             ([], [])
# 1999                                             ([], [])
# 2014                    ([livorno, hellas-verona-fc], [])
# 2012                              ([siena, atalanta], [])
# 2002                                             ([], [])
# 2015                ([empoli-fc, palermo, ac-cesena], [])
# 2011                    ([lecce, brescia, ac-cesena], [])
# 2001                                             ([], [])
# 2017         ([fc-crotone, cagliari, pescara-calcio], [])
# 2009                       ([lecce, bologna, chievo], [])
# 2019                          ([empoli-fc, parma-fc], [])
# 1998           ([empoli-fc, lecce, brescia, as-bari], [])
# 2003                                             ([], [])
# 2013         ([sampdoria, pescara-calcio, torino-fc], [])
# 2016                               ([bologna, carpi], [])
# 2020             ([lecce, brescia, hellas-verona-fc], [])
# 1997           ([perugia, bologna, hellas-verona-fc], [])
#
#                                                bundesliga  \
# season
# 1991                  ([hertha-bsc, wattenscheid-09], [])
# 1996            ([hansa-rostock, fortuna-dusseldorf], [])
# 1990                                             ([], [])
# 2005                            ([arminia-bielefeld], [])
# 2006            ([msv-duisburg, eintracht-frankfurt], [])
# 2021                            ([arminia-bielefeld], [])
# 1994    ([msv-duisburg, lokomotive-leipzig, sc-freibur...
# 2007    ([bochum, energie-cottbus, alemannia-aachen], [])
# 2018                                  ([hannover-96], [])
# 2008    ([hansa-rostock, karlsruher-sc, msv-duisburg],...
# 2010                                  ([sc-freiburg], [])
# 1993                ([saarbrucken, kfc-uerdingen-05], [])
# 2000         ([arminia-bielefeld, unterhaching, ulm], [])
# 1995       ([bochum, kfc-uerdingen-05, 1860-munchen], [])
# 1992    ([msv-duisburg, hansa-rostock, sg-dynamo-dresd...
# 2004             ([eintracht-frankfurt, sc-freiburg], [])
# 1999             ([eintracht-frankfurt, sc-freiburg], [])
# 2014                                   ([hertha-bsc], [])
# 2012                      ([hertha-bsc, fc-augsburg], [])
# 2002                                             ([], [])
# 2015                                    ([paderborn], [])
# 2011                               ([kaiserslautern], [])
# 2001                      ([bochum, energie-cottbus], [])
# 2017                      ([rb-leipzig, sc-freiburg], [])
# 2009                          ([tsg-1899-hoffenheim], [])
# 2019                           ([fortuna-dusseldorf], [])
# 1998        ([hertha-bsc, kaiserslautern, wolfsburg], [])
# 2003       ([arminia-bielefeld, bochum, hannover-96], [])
# 2013    ([greuther-furth, fortuna-dusseldorf, eintrach...
# 2016               ([darmstadt-98, fc-ingolstadt-04], [])
# 2020                                    ([paderborn], [])
# 1997      ([arminia-bielefeld, msv-duisburg, bochum], [])
#
#                                                    2_liga  \
# season
# 1991    ([vfb-oldenburg, havelse, schweinfurt], [waldh...
# 1996    ([arminia-bielefeld, lubeck, fc-carl-zeiss-jen...
# 1990                                             ([], [])
# 2005    ([sg-dynamo-dresden, rot-weib-erfurt, saarbruc...
# 2006    ([kickers-offenbach, paderborn, sportfreunde-s...
# 2021    ([wurzburger-kickers], [fortuna-dusseldorf, pa...
# 1994    ([tennis-borussia, rot-weiss-essen, 1860-munch...
# 2007    ([tus-koblenz, fc-augsburg, rot-weiss-essen, f...
# 2018    ([msv-duisburg, ssv-jahn-regensburg, holstein-...
# 2008    ([vfl-osnabruck, tsg-1899-hoffenheim], [aleman...
# 2010    ([fortuna-dusseldorf, paderborn], [arminia-bie...
# 1993    ([unterhaching, hannover-96, wolfsburg, fc-rem...
# 2000    ([kickers-offenbach, waldhof-mannheim, alemann...
# 1995    ([fsv-frankfurt, zwickau, fortuna-dusseldorf],...
# 1992    ([rot-weib-erfurt, hallescher-fc, lokomotive-l...
# 2004    ([ssv-jahn-regensburg, fc-erzgebirge-aue, unte...
# 1999    ([tennis-borussia, ulm, hannover-96], [arminia...
# 2014    ([arminia-bielefeld, karlsruher-sc], [greuther...
# 2012    ([hansa-rostock, sg-dynamo-dresden], [eintrach...
# 2002    ([babelsberg, karlsruher-sc, schweinfurt], [bo...
# 2015         ([heidenheim, rb-leipzig, darmstadt-98], [])
# 2011    ([vfl-osnabruck, fc-erzgebirge-aue, fc-ingolst...
# 2001    ([reutlingen, saarbrucken, rot-weiss-ahlen, vf...
# 2017    ([sg-dynamo-dresden, fc-erzgebirge-aue, wurzbu...
# 2009    ([fsv-frankfurt, rot-weiss-ahlen, fc-ingolstad...
# 2019             ([magdeburg, paderborn], [hamburger-sv])
# 1998    ([greuther-furth, wattenscheid-09, energie-cot...
# 2003    ([lubeck, eintracht-trier, wacker-burghausen],...
# 2013    ([ssv-jahn-regensburg, sv-sandhausen, vfr-aale...
# 2016    ([arminia-bielefeld, msv-duisburg], [paderborn...
# 2020    ([wehen-wiesbaden, karlsruher-sc, vfl-osnabruc...
# 1997    ([rot-weiss-essen, gutersloh, vfb-oldenburg, s...
#
#                                                   ligue_2  \
# season
# 1991                                             ([], [])
# 1996                                             ([], [])
# 1990                                             ([], [])
# 2005    ([dijon-fco, stade-brestois-29, stade-reims], ...
# 2006         ([valenciennes-afc], [caen, istres, bastia])
# 2021              ([dunkerque], [toulouse-fc, amiens-sc])
# 1994                                             ([], [])
# 2007    ([libourne-saint, chamois-niortais, tours-fc],...
# 2018    ([berrichonne-chateauroux, quevilly], [nancy, ...
# 2008    ([us-boulogne, angers-sco, clermont-foot], [tr...
# 2010    ([arles, stade-lavallois, istres], [caen, nant...
# 1993                                             ([], [])
# 2000    ([creteil-lusitanos, lohuans-cuiseaux], [lorie...
# 1995                      ([], [toulouse-fc, angers-sco])
# 1992                                             ([], [])
# 2004    ([beasancon, angers-sco, rouen-1899], [troyes,...
# 1999    ([ajaccio, sedan], [as-cannes, berrichonne-cha...
# 2014    ([metz, ca-bastia, creteil-lusitanos], [troyes...
# 2012    ([guingamp, amiens-sc, bastia], [arles, monaco...
# 2002    ([amiens-sc, grenoble-foot-38, istres], [stras...
# 2015    ([gazelec-ajaccio, orleans], [ajaccio, sochaux...
# 2011    ([troyes, evian-thonon-gaillard, stade-reims],...
# 2001    ([angers-sco, fc-martigues, as-beauvais], [mon...
# 2017    ([strasbourg, amiens-sc, orleans], [troyes, ga...
# 2009    ([tours-fc, vannes-olympique-club], [strasbour...
# 2019    ([red-star, beziers, grenoble-foot-38], [troye...
# 1998        ([waquehal], [caen, nice, lillestrom, nancy])
# 2003    ([toulouse-fc, clermont-foot, valence, stade-r...
# 2013    ([chamois-niortais, gazelec-ajaccio], [auxerre...
# 2016    ([red-star, bourg-peronnas], [evian-thonon-gai...
# 2020                 ([chambly, rodez], [caen, guingamp])
# 1997    ([troyes, stade-briochin, as-beauvais, sportin...
#
#                                              championship  \
# season
# 1991    ([notts-county, bristol-city-fc, bristol-rover...
# 1996    ([huddersfield-town-fc, birmingham-city-fc], [...
# 1990                                             ([], [])
# 2005    ([brighton-amp-hov, plymouth-argyle, queens-pa...
# 2006    ([], [crystal-palace-fc, southampton-fc, norwi...
# 2021                                             ([], [])
# 1994    ([stoke-city, bolton-wanderers-fc, west-bromwi...
# 2007                                             ([], [])
# 2018                                             ([], [])
# 2008                                             ([], [])
# 2010                                             ([], [])
# 1993    ([brentford, peterborough-u, birmingham-city-f...
# 2000    ([fulham, walsall], [nottingham-forest-fc, bla...
# 1995    ([port-vale, burnley-fc, reading-fc], [swindon...
# 1992    ([cambridge-united, tranmere-rovers, grimsby-t...
# 2004    ([wigan-athletic, crewe-alexandra, cardiff-cit...
# 1999    ([watford-fc, grimsby-town, bristol-city-fc], ...
# 2014                                             ([], [])
# 2012                                             ([], [])
# 2002    ([walsall, millwall-fc, rotherham-united], [co...
# 2015                                             ([], [])
# 2011                                             ([], [])
# 2001    ([gillingham, preston-north-end, burnley-fc], ...
# 2017                                             ([], [])
# 2009                                             ([], [])
# 2019                                             ([], [])
# 1998    ([bury, stockport-county, crewe-alexandra], [n...
# 2003    ([brighton-amp-hov, stoke-city, reading-fc], [...
# 2013                                             ([], [])
# 2016                                             ([], [])
# 2020                                             ([], [])
# 1997    ([swindon-town, bradford-city, oxford-city], [...
#
#                                             primeira_liga  \
# season
# 1991    ([salgueiros, gil-vicente, farense, famalicao]...
# 1996                ([fc-felgueiras, campomaiorense], [])
# 1990                                             ([], [])
# 2005           ([vitoria-setubal, penafiel, estoril], [])
# 2006       ([pacos-ferreira, estrela-amadora, naval], [])
# 2021                            ([nacional, farense], [])
# 1994    ([vitoria-setubal, uniao-madeira, estrela-amad...
# 2007                   ([desportivo-aves, beira-mar], [])
# 2018                ([portimonense, desportivo-aves], [])
# 2008                   ([vitoria-guimaraes, leixoes], [])
# 2010                   ([sc-olhanense, uniao-leiria], [])
# 1993                ([tirsense, espinho, belenenses], [])
# 2000         ([gil-vicente, santa-clara, belenenses], [])
# 1995               ([chaves, tirsense, uniao-leiria], [])
# 1992           ([pacos-ferreira, torreense, estoril], [])
# 2004            ([rio-ave, estrela-amadora, alverca], [])
# 1999             ([alverca, uniao-leiria, beira-mar], [])
# 2014                           ([belenenses, arouca], [])
# 2012                        ([gil-vicente, feirense], [])
# 2002         ([vitoria-setubal, santa-clara, varzim], [])
# 2015            ([boavista, penafiel, moreirense-fc], [])
# 2011                      ([portimonense, beira-mar], [])
# 2001    ([pacos-ferreira, desportivo-aves, beira-mar],...
# 2017                             ([chaves, feirense], [])
# 2009                            ([trofense, rio-ave], [])
# 2019                        ([nacional, santa-clara], [])
# 1998            ([academica, campomaiorense, varzim], [])
# 2003           ([nacional, academica, moreirense-fc], [])
# 2013                       ([moreirense-fc, estoril], [])
# 2016                       ([tondela, uniao-madeira], [])
# 2020       ([pacos-ferreira, gil-vicente, famalicao], [])
# 1997            ([vitoria-setubal, espinho, rio-ave], [])
#
#                                                   serie_b  \
# season
# 1991                                             ([], [])
# 1996    ([bologna, reggina, us-avellino, pistoiese], [...
# 1990                                             ([], [])
# 2005    ([fc-catanzaro, fc-crotone, ac-arezzo, ac-cese...
# 2006    ([bologna, atalanta, rimini-calcio, ac-mantova...
# 2021    ([ac-monza-brianza-1912, reggina, vicenza-calc...
# 1994                                             ([], [])
# 2007    ([genoa, napoli, asd-spezia], [juventus-fc, tr...
# 2018    ([us-cremonese, parma-fc, venezia], [empoli-fc...
# 2008    ([us-avellino, us-grosseto], [ascoli, chievo, ...
# 2010    ([fc-crotone, ac-cesena, gallipoli-calcio], [l...
# 1993                                             ([], [])
# 2000    ([empoli-fc, salernitana-calcio-1919, sampdori...
# 1995                                             ([], [])
# 1992                                             ([], [])
# 2004    ([treviso, como, atalanta, uc-albinoleffe, fio...
# 1999    ([us-cremonese, ac-cesena, ternana-calcio], [j...
# 2014    ([us-avellino, trapani, latina, carpi], [siena...
# 2012    ([ss-juve-stabia, nocerina, hellas-verona-fc],...
# 2002    ([como, as-bari, napoli, modena-fc, vicenza-ca...
# 2015    ([perugia, us-pro-vercelli-calcio, vicenza-cal...
# 2011    ([pescara-calcio, as-varese-1910], [siena, ata...
# 2001    ([siena, piacenza, cagliari, torino-fc, as-cit...
# 2017    ([spal-1907, as-cittadella, benevento-calcio],...
# 2009    ([salernitana-calcio-1919, as-cittadella], [em...
# 2019    ([lecce, nuova-cosenza, livorno], [fc-crotone,...
# 1998    ([treviso, ac-monza-brianza-1912, fidelis-andr...
# 2003    ([ascoli, catania, livorno], [juventus-fc, par...
# 2013    ([ternana-calcio, us-pro-vercelli-calcio, ss-v...
# 2016    ([salernitana-calcio-1919, ascoli, como], [cag...
# 2020    ([ss-juve-stabia, pordenone, trapani, virtus-e...
# 1997    ([empoli-fc, lecce, castel-sangro], [us-cremon...
#
#                                              segunda_liga  \
# season
# 1991                                             ([], [])
# 1996                                             ([], [])
# 1990                                             ([], [])
# 2005    ([sc-olhanense, espinho, varzim, gondomar], [p...
# 2006    ([vizela, sporting-covilha, feirense, fc-maia,...
# 2021    ([cova-piedade, vizela, feirense, academico-vi...
# 1994                                             ([], [])
# 2007    ([trofense, portimonense, gondomar], [vitoria-...
# 2018    ([famalicao, cova-piedade, sporting-covilha, p...
# 2008    ([sc-freamunde, fatima, vizela, santa-clara, g...
# 2010    ([varzim, santa-clara, chaves, gil-vicente, es...
# 1993                                             ([], [])
# 2000    ([fc-felgueiras, uniao-lamas, espinho, sportin...
# 1995                                             ([], [])
# 1992                                             ([], [])
# 2004    ([estoril, desportivo-aves, leixoes], [vitoria...
# 1999    ([uniao-madeira, moreirense-fc, santa-clara], ...
# 2014    ([trofense, atletico-cp, maritimo-ii, santa-cl...
# 2012                          ([], [portimonense, naval])
# 2002    ([rio-ave, nacional, moreirense-fc, chaves], [...
# 2015    ([sc-freamunde, farense, porto-ii, benfica-ii,...
# 2011    ([moreirense-fc, sporting-covilha, feirense], ...
# 2001    ([sc-freamunde, academica, penafiel, fc-marco]...
# 2017    ([sc-freamunde, benfica-ii, leixoes], [uniao-m...
# 2009    ([feirense, sc-olhanense, beira-mar], [boavist...
# 2019    ([penafiel, benfica-ii, farense, varzim], [pac...
# 1998                                             ([], [])
# 2003    ([portimonense, fc-felgueiras, penafiel, fc-ma...
# 2013                                             ([], [])
# 2016    ([sporting-cp-ii, academico-viseu, varzim, atl...
# 2020    ([academica, mafra], [chaves, nacional, feiren...
# 1997                                             ([], [])
#
#                                                eredivisie  \
# season
# 1991                              ([svv, heerenveen], [])
# 1996                  ([fortuna-sittard, graafschap], [])
# 1990                                             ([], [])
# 2005                     ([fc-den-bosch, graafschap], [])
# 2006                   ([heracles, sparta-rotterdam], [])
# 2021                                             ([], [])
# 1994                   ([vvv, heerenveen, nac-breda], [])
# 2007                                    ([excelsior], [])
# 2018                               ([vvv, nac-breda], [])
# 2008                              ([vvv, graafschap], [])
# 2010                            ([vvv, rkc-waalwijk], [])
# 1993    ([sc-cambuur-leeuwarden, fc-den-bosch, go-ahea...
# 2000                                 ([fc-den-bosch], [])
# 1995                            ([fc-dordrecht, nec], [])
# 1992                ([fc-dordrecht, vvv, graafschap], [])
# 2004                    ([fc-volendam, ado-den-haag], [])
# 1999                    ([sc-cambuur-leeuwarden, az], [])
# 2014       ([sc-cambuur-leeuwarden, go-ahead-eagles], [])
# 2012                                 ([rkc-waalwijk], [])
# 2002                                 ([fc-den-bosch], [])
# 2015           ([fc-dordrecht, excelsior, willem-ii], [])
# 2011                        ([graafschap, excelsior], [])
# 2001                 ([fc-groningen, nac-breda, rbc], [])
# 2017            ([sparta-rotterdam, go-ahead-eagles], [])
# 2009                    ([fc-volendam, ado-den-haag], [])
# 2019           ([fortuna-sittard, graafschap, emmen], [])
# 1998                                          ([mvv], [])
# 2003                    ([excelsior, fc-zwolle, rbc], [])
# 2013                         ([fc-zwolle, willem-ii], [])
# 2016                     ([roda-jc, graafschap, nec], [])
# 2020    ([sparta-rotterdam, fc-twente-1965, rkc-waalwi...
# 1997                                           ([az], [])
#
#                                          primera_division
# season
# 1991              ([betis, espanyol, real-burgos-cf], [])
# 1996         ([salamanca, merida-cp, rayo-vallecano], [])
# 1990                                             ([], [])
# 2005                    ([numancia, getafe, levante], [])
# 2006                         ([celta, cadiz, alaves], [])
# 2021                         ([cadiz, huesca, elche], [])
# 1994                ([ue-lleida, valladolid, racing], [])
# 2007     ([gimnastic-tarragona, recreativo, levante], [])
# 2018                   ([girona-fc, getafe, levante], [])
# 2008             ([real-murcia, almeria, valladolid], [])
# 2010               ([real-zaragoza, xerez, tenerife], [])
# 1993                        ([celta, rayo-vallecano], [])
# 2000    ([numancia, malaga, sevilla, rayo-vallecano], [])
# 1995               ([betis, sd-compostela, espanyol], [])
# 1992                          ([albacete, deportivo], [])
# 2004         ([real-zaragoza, real-murcia, albacete], [])
# 1999           ([cf-extremadura, villarreal, alaves], [])
# 2014                   ([almeria, villarreal, elche], [])
# 2012               ([betis, granada, rayo-vallecano], [])
# 2002                     ([tenerife, betis, sevilla], [])
# 2015                    ([cordoba, deportivo, eibar], [])
# 2011                            ([hercules, levante], [])
# 2001               ([osasuna, villarreal, ud-palmas], [])
# 2017                     ([leganes, osasuna, alaves], [])
# 2009                             ([numancia, malaga], [])
# 2019           ([huesca, valladolid, rayo-vallecano], [])
# 1998               ([salamanca, mallorca, merida-cp], [])
# 2003                           ([racing, recreativo], [])
# 2013                 ([celta, valladolid, deportivo], [])
# 2016                             ([betis, ud-palmas], [])
# 2020                   ([mallorca, osasuna, granada], [])
# 1997        ([logrones-cd, cf-extremadura, hercules], [])

# %%
fulldf['home_newly_promoted'] = fulldf.apply(lambda row: row.home_team in df_moved_teams.at[row.season,row.league][0], axis=1)
fulldf['home_newly_relegated'] = fulldf.apply(lambda row: row.home_team in df_moved_teams.at[row.season,row.league][1], axis=1)
fulldf['away_newly_promoted'] = fulldf.apply(lambda row: row.away_team in df_moved_teams.at[row.season,row.league][0], axis=1)
fulldf['away_newly_relegated'] = fulldf.apply(lambda row: row.away_team in df_moved_teams.at[row.season,row.league][1], axis=1)
fulldf
# Out:
#                                                   link            referee  \
# 0          /match/saarbrucken/stuttgarter-kickers/1990  Hans-Jürgen Weber
# 1                  /match/saarbrucken/hannover-96/1990      Eugen Strigel
# 2                       /match/saarbrucken/meppen/1990     Siegbert Rubel
# 3       /match/saarbrucken/blau-weiss-1890-berlin/1990  Wilfried Heitmann
# 4                /match/saarbrucken/vfl-osnabruck/1990     Karl Gangkofer
# ...                                                ...                ...
# 109242                       /match/bourges/nancy/1994         Marc Flosi
# 109243                    /match/bourges/red-star/1994
# 109244                       /match/bourges/sedan/1994    Stéphane Moulin
# 109245            /match/bourges/chamois-niortais/1994        Hervé Bayet
# 109246                   /match/bourges/dunkerque/1994       Stéphane Bré
#
#         home_yellow  home_red  away_yellow  away_red             date_dt  \
# 0               0.0       0.0          3.0       0.0 1989-07-29 15:00:00
# 1               0.0       0.0          3.0       0.0 1989-08-12 15:00:00
# 2               0.0       0.0          3.0       0.0 1989-08-23 19:30:00
# 3               0.0       0.0          0.0       0.0 1989-09-02 15:00:00
# 4               1.0       0.0          2.0       0.0 1989-09-17 15:00:00
# ...             ...       ...          ...       ...                 ...
# 109242          0.0       0.0          0.0       1.0 1993-09-01 00:00:00
# 109243          0.0       0.0          0.0       1.0 1994-03-05 00:00:00
# 109244          0.0       0.0          0.0       1.0 1993-09-11 00:00:00
# 109245          0.0       0.0          0.0       0.0 1993-10-27 00:00:00
# 109246          0.0       0.0          0.0       1.0 1993-08-04 00:00:00
#
#           home_team               away_team season result  round   league  \
# 0       saarbrucken     stuttgarter-kickers   1990    1-0      1   2_liga
# 1       saarbrucken             hannover-96   1990    2-0      3   2_liga
# 2       saarbrucken                  meppen   1990    4-0      5   2_liga
# 3       saarbrucken  blau-weiss-1890-berlin   1990    1-1      7   2_liga
# 4       saarbrucken           vfl-osnabruck   1990    7-1      9   2_liga
# ...             ...                     ...    ...    ...    ...      ...
# 109242      bourges                   nancy   1994    2-0      9  ligue_2
# 109243      bourges                red-star   1994    0-1     31  ligue_2
# 109244      bourges                   sedan   1994    1-2     10  ligue_2
# 109245      bourges        chamois-niortais   1994    1-1     18  ligue_2
# 109246      bourges               dunkerque   1994    1-1      3  ligue_2
#
#         home_goals  away_goals  total_goals  outcome         city  country  \
# 0                1           0            1        3  Saarbrücken  Germany
# 1                2           0            2        3  Saarbrücken  Germany
# 2                4           0            4        3  Saarbrücken  Germany
# 3                1           1            2        2  Saarbrücken  Germany
# 4                7           1            8        3  Saarbrücken  Germany
# ...            ...         ...          ...      ...          ...      ...
# 109242           2           0            2        3      Bourges   France
# 109243           0           1            1        4      Bourges   France
# 109244           1           2            3        4      Bourges   France
# 109245           1           1            2        2      Bourges   France
# 109246           1           1            2        2      Bourges   France
#
#                     stadium  capacity    pitch  elo_home  elo_away link_index  \
# 0       Stadion Ludwigspark     35286  Natural      56.0      59.0       3487
# 1       Stadion Ludwigspark     35286  Natural      56.0      60.0       3507
# 2       Stadion Ludwigspark     35286  Natural      57.0      53.0       3533
# 3       Stadion Ludwigspark     35286  Natural      57.0      56.0       3553
# 4       Stadion Ludwigspark     35286  Natural      57.0      52.0       3575
# ...                     ...       ...      ...       ...       ...        ...
# 109242                  NaN     13000      NaN       NaN       NaN      35314
# 109243                  NaN     13000      NaN       NaN       NaN      35553
# 109244                  NaN     13000      NaN       NaN       NaN      35322
# 109245                  NaN     13000      NaN       NaN       NaN      35411
# 109246                  NaN     13000      NaN       NaN       NaN      35251
#
#         home_newly_promoted  home_newly_relegated  away_newly_promoted  \
# 0                     False                 False                False
# 1                     False                 False                False
# 2                     False                 False                False
# 3                     False                 False                False
# 4                     False                 False                False
# ...                     ...                   ...                  ...
# 109242                False                 False                False
# 109243                False                 False                False
# 109244                False                 False                False
# 109245                False                 False                False
# 109246                False                 False                False
#
#         away_newly_relegated
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 109242                 False
# 109243                 False
# 109244                 False
# 109245                 False
# 109246                 False
#
# [109247 rows x 29 columns]

# %%
# drop the items missing elo
print(fulldf.size)
fulldf.dropna(subset=['elo_home','elo_away'],inplace=True)
print(fulldf.size)
# Out:
# 3168163
# 2959334

# %% [markdown]
# # Winning / losing streaks
